# %%
import pandas as pd

# %%
std = pd.read_csv("datasets/student_marks.csv")
std
# Out:
#    Student  StudyHours  FinalMarks
# 0    Aarav         1.0          28
# 1   Aayush         2.0          35
# 2     Sita         2.5          40
# 3      Ram         3.0          45
# 4   Anisha         3.5          50
# 5    Rohan         4.0          55
# 6    Priya         4.5          60
# 7    Kiran         5.0          65
# 8    Nabin         5.5          70
# 9    Suman         6.0          74
# 10  Alisha         6.5          79
# 11  Bikash         7.0          84
# 12  Sabina         7.5          88
# 13  Roshan         8.0          92
# 14    Puja         9.0          98

# %%
print(std.head())
# Out:
#   Student  StudyHours  FinalMarks
# 0   Aarav         1.0          28
# 1  Aayush         2.0          35
# 2    Sita         2.5          40
# 3     Ram         3.0          45
# 4  Anisha         3.5          50

# %%
print(std.shape)
print(std.dtypes)
std.isnull().sum
# Out:
# (15, 3)
# Student           str
# StudyHours    float64
# FinalMarks      int64
# dtype: object
# <bound method DataFrame.sum of     Student  StudyHours  FinalMarks
# 0     False       False       False
# 1     False       False       False
# 2     False       False       False
# 3     False       False       False
# 4     False       False       False
# 5     False       False       False
# 6     False       False       False
# 7     False       False       False
# 8     False       False       False
# 9     False       False       False
# 10    False       False       False
# 11    False       False       False
# 12    False       False       False
# 13    False       False       False
# 14    False       False       False>

# %%
X = std[["StudyHours"]]
y = std["FinalMarks"]
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2
)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)

print("Coefficient:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Coefficient: 9.226918798665185
# Intercept: 17.88431590656284

# %%
study_hours = pd.DataFrame({
    "StudyHours": [2, 4, 6]
})
predicted_marks = model.predict(study_hours)
print(predicted_marks)
# Out:
# [36.3381535 54.7919911 73.2458287]
