# %%
import pandas as pd

# %%
lms = pd.read_csv("datasets/LMS_Dirty_Dataset.csv")
lms
# Out:
#      student_id student_name             course        city  age  gender  \
# 0             1         Gita         MERN Stack   Kathmandu   17  Female
# 1             2        Nabin       Data Science     Itahari   29  Female
# 2             3         Gita         MERN Stack      Dharan   20  Female
# 3             4         Gita  Digital Marketing     Itahari   20  Female
# 4             5         Gita       Data Science     Itahari   19    Male
# ..          ...          ...                ...         ...  ...     ...
# 345         346         Hari              UI/UX      Dharan   21  Female
# 346         347       Anisha  Digital Marketing  Biratnagar   31  Female
# 347         348         Sita            Flutter  Biratnagar   19    Male
# 348         349       Anisha              UI/UX     Itahari   27    Male
# 349         350         Hari  Python with AI/ML      Dharan   19  Female
#
#     enrollment_date  course_fee  discount payment_status  attendance_percent  \
# ...

# %%
print(lms.head(10))
# Out:
#    student_id student_name             course        city  age  gender  \
# 0           1         Gita         MERN Stack   Kathmandu   17  Female
# 1           2        Nabin       Data Science     Itahari   29  Female
# 2           3         Gita         MERN Stack      Dharan   20  Female
# 3           4         Gita  Digital Marketing     Itahari   20  Female
# 4           5         Gita       Data Science     Itahari   19    Male
# 5           6       Anisha       Data Science      Dharan   18    Male
# 6           7        Suman         MERN Stack      Dharan   33  Female
# 7           8         Sita         MERN Stack     Pokhara   28  Female
# 8           9         Gita            Flutter  Biratnagar   31    Male
# 9          10         Sita            Flutter      Dharan   25  Female
#
#   enrollment_date  course_fee  discount payment_status  attendance_percent  \
# 0      2026-02-24       10000        10        Pending                73.0
# ...

# %%
print(lms.tail(10))
# Out:
#      student_id student_name             course        city  age  gender  \
# 340         341         Hari  Digital Marketing  Biratnagar   31  Female
# 341         342         Gita            Flutter  Biratnagar   32  Female
# 342         343        Aarav              UI/UX     Itahari   18    Male
# 343         344         Gita  Python with AI/ML   Kathmandu   33    Male
# 344         345         Gita  Digital Marketing     Pokhara   29    Male
# 345         346         Hari              UI/UX      Dharan   21  Female
# 346         347       Anisha  Digital Marketing  Biratnagar   31  Female
# 347         348         Sita            Flutter  Biratnagar   19    Male
# 348         349       Anisha              UI/UX     Itahari   27    Male
# 349         350         Hari  Python with AI/ML      Dharan   19  Female
#
#     enrollment_date  course_fee  discount payment_status  attendance_percent  \
# 340      2026-06-10        5000        20        Pending                96.0
# ...

# %%
print(lms.shape)
# Out:
# (350, 18)

# %%
print(lms.columns)
# Out:
# Index(['student_id', 'student_name', 'course', 'city', 'age', 'gender',
#        'enrollment_date', 'course_fee', 'discount', 'payment_status',
#        'attendance_percent', 'assignment_score', 'final_score', 'rating',
#        'mentor', 'phone', 'email', 'completion_status'],
#       dtype='str')

# %%
print(lms.dtypes)
# Out:
# student_id              int64
# student_name              str
# course                    str
# city                      str
# age                     int64
# gender                    str
# enrollment_date           str
# course_fee              int64
# discount                int64
# payment_status            str
# attendance_percent    float64
# assignment_score        int64
# final_score             int64
# rating                  int64
# mentor                    str
# phone                     str
# email                     str
# completion_status         str
# dtype: object

# %%
print(lms.describe())
# Out:
#        student_id         age     course_fee    discount  attendance_percent  \
# count  350.000000  350.000000     350.000000  350.000000          349.000000
# mean   175.500000   26.174286   10085.711429    9.600000           70.154728
# std    101.180532    5.485686   53109.214627    7.929489           16.697929
# min      1.000000   17.000000   -5000.000000    0.000000           40.000000
# 25%     88.250000   21.000000    5000.000000    0.000000           58.000000
# 50%    175.500000   27.000000    7000.000000   10.000000           70.000000
# 75%    262.750000   31.000000   10000.000000   20.000000           83.000000
# max    350.000000   35.000000  999999.000000   20.000000          100.000000
#
#        assignment_score  final_score      rating
# count        350.000000   350.000000  350.000000
# mean          67.011429    65.011429    3.960000
# std           20.686773    20.556718    0.817852
# min           -5.000000    30.000000    3.000000
# ...

# %%
lms.duplicated().sum()
lms.drop_duplicates(inplace = True)
lms
# Out:
#      student_id student_name             course        city  age  gender  \
# 0             1         Gita         MERN Stack   Kathmandu   17  Female
# 1             2        Nabin       Data Science     Itahari   29  Female
# 2             3         Gita         MERN Stack      Dharan   20  Female
# 3             4         Gita  Digital Marketing     Itahari   20  Female
# 4             5         Gita       Data Science     Itahari   19    Male
# ..          ...          ...                ...         ...  ...     ...
# 345         346         Hari              UI/UX      Dharan   21  Female
# 346         347       Anisha  Digital Marketing  Biratnagar   31  Female
# 347         348         Sita            Flutter  Biratnagar   19    Male
# 348         349       Anisha              UI/UX     Itahari   27    Male
# 349         350         Hari  Python with AI/ML      Dharan   19  Female
#
#     enrollment_date  course_fee  discount payment_status  attendance_percent  \
# ...

# %%
lms.isnull().sum()
#print(lms[lms["attendance_percent"].isnull()])
lms["attendance_percent"] = lms["attendance_percent"].fillna(lms["attendance_percent"].median())
lms.head(29)
# Out:
#     student_id student_name             course        city  age  gender  \
# 0            1         Gita         MERN Stack   Kathmandu   17  Female
# 1            2        Nabin       Data Science     Itahari   29  Female
# 2            3         Gita         MERN Stack      Dharan   20  Female
# 3            4         Gita  Digital Marketing     Itahari   20  Female
# 4            5         Gita       Data Science     Itahari   19    Male
# 5            6       Anisha       Data Science      Dharan   18    Male
# 6            7        Suman         MERN Stack      Dharan   33  Female
# 7            8         Sita         MERN Stack     Pokhara   28  Female
# 8            9         Gita            Flutter  Biratnagar   31    Male
# 9           10         Sita            Flutter      Dharan   25  Female
# 10          11         Hari  Digital Marketing   Kathmandu   29  Female
# 11          12        Suman              UI/UX  Biratnagar   31    Male
# ...

# %%
lms.dtypes
#print(lms["enrollment_date"])
#lms["enrollment_date"] = pd.to_datetime(lms["enrollment_date"])
#print(lms["enrollment_date"])
# Out:
# student_id                     int64
# student_name                     str
# course                           str
# city                             str
# age                            int64
# gender                           str
# enrollment_date       datetime64[us]
# course_fee                     int64
# discount                       int64
# payment_status                   str
# attendance_percent             int64
# assignment_score               int64
# final_score                    int64
# rating                         int64
# mentor                           str
# phone                            str
# email                            str
# completion_status                str
# dtype: object

# %%
lms["city"] = lms["city"].str.strip().str.title()
lms["course"] = lms["course"].str.strip().str.title()
lms["mentor"] = lms["mentor"].str.strip().str.title()
lms["gender"] = lms["gender"].str.strip().str.title()
lms["payment_status"] = lms["payment_status"].str.strip().str.title()
lms["completion_status"] = lms["completion_status"].str.strip().str.title()

# %%
lms[lms["age"]<0]
lms[lms["course_fee"]<0]
lms[lms["attendance_percent"]<0]
lms[lms["discount"]<0]
lms[lms["attendance_percent"]<0]
lms[lms["assignment_score"]<0]
lms[lms["final_score"]<0]
lms[lms["rating"]<0]
#lms=lms[lms["course_fee"]>0]

# %%
lms[lms["course_fee"]<0]
lms.loc[lms["course_fee"]<0,"course_fee"]=0
lms[lms["assignment_score"]<0]
lms.loc[lms["assignment_score"]<0,"assignment_score"]=0

# %%
Q1 = lms["course_fee"].quantile(0.25)
Q3 = lms["course_fee"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = lms[(lms["course_fee"] < lower) | (lms["course_fee"] > upper)]

print(outliers)
# Out:
#     student_id student_name   course        city  age gender enrollment_date  \
# 8            9         Gita  Flutter  Biratnagar   31   Male      2026-05-06
# 18          19         Sita  Flutter   Kathmandu   24   Male      2026-05-09
#
#     course_fee  discount payment_status  attendance_percent  assignment_score  \
# 8        -5000        10        Pending                70.0                88
# 18      999999        10        Pending                41.0                75
#
#     final_score  rating mentor       phone             email completion_status
# 8            98       4  Ishan  9869507556   user8@gmail.com         Completed
# 18           51       4  Ishan  9803681891  user18@gmail.com           Ongoing

# %%
# Out:
#     student_id student_name   course        city  age gender enrollment_date  \
# 8            9         Gita  Flutter  Biratnagar   31   Male      2026-05-06
# 18          19         Sita  Flutter   Kathmandu   24   Male      2026-05-09
#
#     course_fee  discount payment_status  attendance_percent  assignment_score  \
# 8        -5000        10        Pending                70.0                88
# 18      999999        10        Pending                41.0                75
#
#     final_score  rating mentor       phone             email  \
# 8            98       4  Ishan  9869507556   user8@gmail.com
# 18           51       4  Ishan  9803681891  user18@gmail.com
#
#    completion_status    Z_score
# 8          Completed  -0.284051
# 18           Ongoing  18.639200

# %%
Q1 = lms["attendance_percent"].quantile(0.25)
Q3 = lms["attendance_percent"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = lms[(lms["attendance_percent"] < lower) | (lms["attendance_percent"] > upper)]

print(outliers)
# Out:
# Empty DataFrame
# Columns: [student_id, student_name, course, city, age, gender, enrollment_date, course_fee, discount, payment_status, attendance_percent, assignment_score, final_score, rating, mentor, phone, email, completion_status]
# Index: []

# %%
Q1 = lms["assignment_score"].quantile(0.25)
Q3 = lms["assignment_score"].quantile(0.75)
median=lms["assignment_score"].median()
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = lms[(lms["assignment_score"] < lower) | (lms["assignment_score"] > upper)]

print(outliers)
# Out:
#     student_id student_name        course     city  age  gender  \
# 38          39       Anisha  Data Science  Itahari   20  Female
#
#    enrollment_date  course_fee  discount payment_status  attendance_percent  \
# 38      2026-01-14       10000        10        Pending                70.0
#
#     assignment_score  final_score  rating  mentor       phone  \
# 38                -5           55       3  Manish  9856058698
#
#                email completion_status   Z_score
# 38  user38@gmail.com           Ongoing -0.001614

# %%
Q1 = lms["final_score"].quantile(0.25)
Q3 = lms["final_score"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = lms[(lms["final_score"] < lower) | (lms["final_score"] > upper)]

print(outliers)
# Out:
# Empty DataFrame
# Columns: [student_id, student_name, course, city, age, gender, enrollment_date, course_fee, discount, payment_status, attendance_percent, assignment_score, final_score, rating, mentor, phone, email, completion_status, Z_score]
# Index: []

# %%
mean = lms["course_fee"].mean()
std = lms["course_fee"].std()
lms["Z_score"] = (lms["course_fee"]-mean)/std
outliers=lms[(lms["Z_score"].abs()>3) |(lms["Z_score"].abs()<-3 )]
outliers
# Out:
#     student_id student_name   course       city  age gender enrollment_date  \
# 18          19         Sita  Flutter  Kathmandu   24   Male      2026-05-09
#
#     course_fee  discount payment_status  attendance_percent  assignment_score  \
# 18      999999        10        Pending                41.0                75
#
#     final_score  rating mentor       phone             email  \
# 18           51       4  Ishan  9803681891  user18@gmail.com
#
#    completion_status  Z_score
# 18           Ongoing  18.6392

# %%
lms = lms[(lms["course_fee"] > lower)&(lms["course_fee"] < upper)]

#print(lms_remove)
lms.head(20)
# Out:
#     student_id student_name             course        city  age  gender  \
# 0            1         Gita         MERN Stack   Kathmandu   17  Female
# 1            2        Nabin       Data Science     Itahari   29  Female
# 2            3         Gita         MERN Stack      Dharan   20  Female
# 3            4         Gita  Digital Marketing     Itahari   20  Female
# 4            5         Gita       Data Science     Itahari   19    Male
# 5            6       Anisha       Data Science      Dharan   18    Male
# 6            7        Suman         MERN Stack      Dharan   33  Female
# 7            8         Sita         MERN Stack     Pokhara   28  Female
# 9           10         Sita            Flutter      Dharan   25  Female
# 10          11         Hari  Digital Marketing   Kathmandu   29  Female
# 11          12        Suman              UI/UX  Biratnagar   31    Male
# 12          13          Ram  Python with AI/ML     Pokhara   22    Male
# ...

# %%
Q1 = lms["course_fee"].quantile(0.25)
Q3 = lms["course_fee"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

median = lms["course_fee"].median()

lms.loc[(lms["course_fee"] < lower) | (lms["course_fee"] > upper),"course_fee"] = median
lms.head(20)
# Out:
#     student_id student_name             course        city  age  gender  \
# 0            1         Gita         MERN Stack   Kathmandu   17  Female
# 1            2        Nabin       Data Science     Itahari   29  Female
# 2            3         Gita         MERN Stack      Dharan   20  Female
# 3            4         Gita  Digital Marketing     Itahari   20  Female
# 4            5         Gita       Data Science     Itahari   19    Male
# 5            6       Anisha       Data Science      Dharan   18    Male
# 6            7        Suman         MERN Stack      Dharan   33  Female
# 7            8         Sita         MERN Stack     Pokhara   28  Female
# 8            9         Gita            Flutter  Biratnagar   31    Male
# 9           10         Sita            Flutter      Dharan   25  Female
# 10          11         Hari  Digital Marketing   Kathmandu   29  Female
# 11          12        Suman              UI/UX  Biratnagar   31    Male
# ...

# %%
Q1 = lms["course_fee"].quantile(0.25)
Q3 = lms["course_fee"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

lms["course_fee"] = lms["course_fee"].clip(lower, upper)

lms.head(20)
# Out:
#     student_id student_name             course        city  age  gender  \
# 0            1         Gita         MERN Stack   Kathmandu   17  Female
# 1            2        Nabin       Data Science     Itahari   29  Female
# 2            3         Gita         MERN Stack      Dharan   20  Female
# 3            4         Gita  Digital Marketing     Itahari   20  Female
# 4            5         Gita       Data Science     Itahari   19    Male
# 5            6       Anisha       Data Science      Dharan   18    Male
# 6            7        Suman         MERN Stack      Dharan   33  Female
# 7            8         Sita         MERN Stack     Pokhara   28  Female
# 8            9         Gita            Flutter  Biratnagar   31    Male
# 9           10         Sita            Flutter      Dharan   25  Female
# 10          11         Hari  Digital Marketing   Kathmandu   29  Female
# 11          12        Suman              UI/UX  Biratnagar   31    Male
# ...

# %%
Q1 = lms["assignment_score"].quantile(0.25)
Q3 = lms["assignment_score"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
lower
upper = Q3 + 1.5 * IQR
lms = lms[(lms["assignment_score"] > lower)&(lms["assignment_score"] < upper)]
lms.head(42)
# Out:
#     student_id student_name             course        city  age  gender  \
# 0            1         Gita         MERN Stack   Kathmandu   17  Female
# 1            2        Nabin       Data Science     Itahari   29  Female
# 2            3         Gita         MERN Stack      Dharan   20  Female
# 3            4         Gita  Digital Marketing     Itahari   20  Female
# 4            5         Gita       Data Science     Itahari   19    Male
# 5            6       Anisha       Data Science      Dharan   18    Male
# 6            7        Suman         MERN Stack      Dharan   33  Female
# 7            8         Sita         MERN Stack     Pokhara   28  Female
# 8            9         Gita            Flutter  Biratnagar   31    Male
# 9           10         Sita            Flutter      Dharan   25  Female
# 10          11         Hari  Digital Marketing   Kathmandu   29  Female
# 11          12        Suman              UI/UX  Biratnagar   31    Male
# ...

# %%
Q1 = lms["assignment_score"].quantile(0.25)
Q3 = lms["assignment_score"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

median = lms["assignment_score"].median()

lms.loc[(lms["assignment_score"] < lower) | (lms["assignment_score"] > upper),"assignment_score"] = median
lms.head(40)
# Out:
#     student_id student_name             course        city  age  gender  \
# 0            1         Gita         MERN Stack   Kathmandu   17  Female
# 1            2        Nabin       Data Science     Itahari   29  Female
# 2            3         Gita         MERN Stack      Dharan   20  Female
# 3            4         Gita  Digital Marketing     Itahari   20  Female
# 4            5         Gita       Data Science     Itahari   19    Male
# 5            6       Anisha       Data Science      Dharan   18    Male
# 6            7        Suman         MERN Stack      Dharan   33  Female
# 7            8         Sita         MERN Stack     Pokhara   28  Female
# 8            9         Gita            Flutter  Biratnagar   31    Male
# 9           10         Sita            Flutter      Dharan   25  Female
# 10          11         Hari  Digital Marketing   Kathmandu   29  Female
# 11          12        Suman              UI/UX  Biratnagar   31    Male
# ...

# %%
Q1 = lms["assignment_score"].quantile(0.25)
Q3 = lms["assignment_score"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

lms["assignment_score"] = lms["assignment_score"].clip(lower, upper)

lms.head(40)
# Out:
#     student_id student_name             course        city  age  gender  \
# 0            1         Gita         MERN Stack   Kathmandu   17  Female
# 1            2        Nabin       Data Science     Itahari   29  Female
# 2            3         Gita         MERN Stack      Dharan   20  Female
# 3            4         Gita  Digital Marketing     Itahari   20  Female
# 4            5         Gita       Data Science     Itahari   19    Male
# 5            6       Anisha       Data Science      Dharan   18    Male
# 6            7        Suman         MERN Stack      Dharan   33  Female
# 7            8         Sita         MERN Stack     Pokhara   28  Female
# 8            9         Gita            Flutter  Biratnagar   31    Male
# 9           10         Sita            Flutter      Dharan   25  Female
# 10          11         Hari  Digital Marketing   Kathmandu   29  Female
# 11          12        Suman              UI/UX  Biratnagar   31    Male
# ...

# %%
mean = lms["course_fee"].mean()
std = lms["course_fee"].std()
lms["Z_score"] = (lms["course_fee"]-mean)/std
outliers=lms[(lms["Z_score"].abs()>3) |(lms["Z_score"].abs()<-3 )]
outliers
# Out:
#     student_id student_name   course       city  age gender enrollment_date  \
# 18          19         Sita  Flutter  Kathmandu   24   Male      2026-05-09
#
#     course_fee  discount payment_status  attendance_percent  assignment_score  \
# 18      999999        10        Pending                41.0                75
#
#     final_score  rating mentor       phone             email  \
# 18           51       4  Ishan  9803681891  user18@gmail.com
#
#    completion_status  Z_score
# 18           Ongoing  18.6392

# %%
mean = lms["attendance_percent"].mean()
std = lms["attendance_percent"].std()
lms["Z_score"] = (lms["attendance_percent"]-mean)/std
outliers=lms[(lms["Z_score"].abs()>3) |(lms["Z_score"].abs()<-3 )]
outliers
# Out:
# Empty DataFrame
# Columns: [student_id, student_name, course, city, age, gender, enrollment_date, course_fee, discount, payment_status, attendance_percent, assignment_score, final_score, rating, mentor, phone, email, completion_status, Z_score]
# Index: []

# %%
mean = lms["assignment_score"].mean()
std = lms["assignment_score"].std()
lms["Z_score"] = (lms["assignment_score"]-mean)/std
outliers=lms[(lms["Z_score"].abs()>3) |(lms["Z_score"].abs()<-3 )]
outliers
# Out:
#     student_id student_name        course     city  age  gender  \
# 38          39       Anisha  Data Science  Itahari   20  Female
#
#    enrollment_date  course_fee  discount payment_status  attendance_percent  \
# 38      2026-01-14       10000        10        Pending                70.0
#
#     assignment_score  final_score  rating  mentor       phone  \
# 38                -5           55       3  Manish  9856058698
#
#                email completion_status   Z_score
# 38  user38@gmail.com           Ongoing -3.481037

# %%
mean = lms["final_score"].mean()
std = lms["final_score"].std()
lms["Z_score"] = (lms["final_score"]-mean)/std
outliers=lms[(lms["Z_score"].abs()>3) |(lms["Z_score"].abs()<-3 )]
outliers
# Out:
# Empty DataFrame
# Columns: [student_id, student_name, course, city, age, gender, enrollment_date, course_fee, discount, payment_status, attendance_percent, assignment_score, final_score, rating, mentor, phone, email, completion_status, Z_score]
# Index: []
