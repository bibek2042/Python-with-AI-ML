# %%
import pandas as pd

# %%
dd = pd.read_csv("datasets/daraz_dataset.csv")
#print(dd)
#print(dd.shape)
#print(dd.columns)
#print(dd.info())
#print(dd["TotalAmount"].max())
#print(dd["TotalAmount"].min())
#print(dd["TotalAmount"].mean())
#print(dd[["CustomerName","District","TotalAmount"]])
#print(dd.iloc[11])  11 index ko rows lai tanyo
#print(dd.iloc[0:5])
#print(dd.iloc[0,2]) specific cell lai capture garna sakinxa
#print(dd.iloc[:,[2,6,8]])
#print(dd.iloc[-1])
#print(dd.iloc[0:5,0:3])
#print(dd.loc[:,["District","CustomerName"]])
#print(dd.loc[dd["District"] == "Kathmandu"])
#print(dd.loc[dd["TotalAmount"]>30000])
#filter chaining --- Kathmandu district, esewa paymentMethod
#print(dd.loc[(dd["District"] == "Kathmandu") & (dd["PaymentMethod"] == "eSewa" )])
#Category = "Electronics" & Rating = 5 
#print(dd[(dd["Category"]== "Electronics" ) & (dd["Rating"] == 5 )])
#print(dd.sort_values("TotalAmount"))
print(dd.sort_values("TotalAmount",ascending=False))
# Out:
#       OrderID   OrderDate     CustomerName  Age  Gender    District  \
# 375  DZ100376  2026-02-11       Asha Thapa   18    Male   Bhaktapur
# 271  DZ100272  2026-01-29  Ramesh Adhikari   41    Male     Itahari
# 132  DZ100133  2026-02-04         Sita Rai   52  Female   Bhaktapur
# 435  DZ100436  2026-03-20        Nabin Rai   46    Male      Butwal
# 472  DZ100473  2026-02-22       Sita Karki   42    Male   Kathmandu
# ..        ...         ...              ...  ...     ...         ...
# 94   DZ100095  2026-03-02       Roshan Rai   19    Male  Biratnagar
# 492  DZ100493  2026-05-04     Kiran Sharma   55  Female    Lalitpur
# 74   DZ100075  2026-03-18  Roshan Shrestha   49    Male      Butwal
# 195  DZ100196  2026-05-22    Manish Sharma   19  Female     Chitwan
# 27   DZ100028  2026-02-03     Rohit Basnet   46  Female     Chitwan
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 375        Books           Notebook         5      45982                0
# 271  Electronics  Bluetooth Speaker         5      46482                5
# 132       Sports           Football         5      48481               10
# 435         Home              Chair         5      43252                0
# 472        Books      Python Basics         5      44649                5
# ..           ...                ...       ...        ...              ...
# 94        Sports           Football         2       1273               10
# 492    Groceries             Coffee         1       2781               20
# 74         Books           Notebook         3        468               10
# 195       Sports           Dumbbell         1        733               20
# 27         Books   Data Science 101         1        532               10
#
#      TotalAmount PaymentMethod  Rating OrderStatus
# 375    229910.00       IME Pay       5    Returned
# 271    220789.50       IME Pay       5   Delivered
# 132    218164.50       IME Pay       4     Shipped
# 435    216260.00         eSewa       2     Shipped
# 472    212082.75           COD       1  Processing
# ..           ...           ...     ...         ...
# 94       2291.40         eSewa       2    Returned
# 492      2224.80        Khalti       5   Cancelled
# 74       1263.60          Card       4   Cancelled
# 195       586.40           COD       1  Processing
# 27        478.80         eSewa       1   Delivered
#
# [500 rows x 15 columns]

# %%
bdd = pd.read_csv("datasets/bad_daraz_dataset (1).csv")
bdd
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 2            3        Shoes      Fashion   3500               5%     4.2
# 3            4      T-Shirt      Fashion   1500               20     NaN
# 4            5        Watch  Accessories   5500               10     4.5
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 7            8          Bag      Fashion    abc               12     3.9
# 8            9        Mouse  Electronics   1800                5     4.3
# 9            9          Cup  Electronics   1800                5     4.3
# 10          10     Keyboard  Electronics   2500                5     4.4
# 11          10         Haha  Electronics   2500                5     4.4
# 12          11       Bottle         Home    800                0     5.5
# 13          12        Chair    Furniture  -2500               10     4.0
# 14          12        Chair    Furniture  -2500               10     4.0
#
#            stock       seller         city      brand gender_target      age  \
# 0             25      TechHub    KathMandu       Dell        Unisex       25
# 1             40  GadgetNepal      Pokhara    Samsung        Unisex       30
# 2             60   FashionHub      Itahari       Nike          Male       22
# 3            150        Style   Biratnagar     Adidas        Female   Female
# 4   Out of Stock        TimeX    Kathmandu      Casio          Male       28
# 5             75     AudioPro      Pokhara        JBL        Unisex      24
# 6             25      TechHub    KATHMANDU       Dell        Unisex       25
# 7             45     CarryAll       Dharan  Wildcraft        Female       19
# 8            NaN      TechHub    Kathmandu   Logitech        Unisex      NaN
# 9            NaN      TechHub    Kathmandu   Logitech        Unisex      NaN
# 10            35     TechHub    Kathmandu    Logitech        Unisex       21
# 11            35     TechHub    Kathmandu    Logitech        Unisex       21
# 12           100    HomeStore     Janakpur    Generic        Unisex       26
# 13            -5      FurniCo     Lalitpur       IKEA        Unisex  Unknown
# 14            -5      FurniCo     Lalitpur       IKEA        Unisex  Unknown
#
#     reviews
# 0       120
# 1       210
# 2        55
# 3        30
# 4        80
# 5        65
# 6       120
# 7        18
# 8        90
# 9        90
# 10      110
# 11      110
# 12       12
# 13       44
# 14       44

# %%
bdd.isnull().sum()
#bdd.fillna(0)
print(bdd[["price","discount_percent","rating","stock","age"]])
bdd["price"]=pd.to_numeric(bdd["price"],errors="coerce")
bdd
# Out:
#       price discount_percent  rating         stock      age
# 0   75000.0               10     4.8            25       25
# 1       NaN               15     4.6            40       30
# 2    3500.0               5%     4.2            60       22
# 3    1500.0               20     NaN           150   Female
# 4    5500.0               10     4.5  Out of Stock       28
# 5    4200.0              NaN     4.1            75      24
# 6   75000.0               10     4.8            25       25
# 7       NaN               12     3.9            45       19
# 8    1800.0                5     4.3           NaN      NaN
# 9    1800.0                5     4.3           NaN      NaN
# 10   2500.0                5     4.4            35       21
# 11   2500.0                5     4.4            35       21
# 12    800.0                0     5.5           100       26
# 13  -2500.0               10     4.0            -5  Unknown
# 14  -2500.0               10     4.0            -5  Unknown
#     product_id product_name     category    price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000.0               10     4.8
# 1            2        Phone  Electronics      NaN               15     4.6
# 2            3        Shoes      Fashion   3500.0               5%     4.2
# 3            4      T-Shirt      Fashion   1500.0               20     NaN
# 4            5        Watch  Accessories   5500.0               10     4.5
# 5            6   Headphones  Electronics   4200.0              NaN     4.1
# 6            7       Laptop  Electronics  75000.0               10     4.8
# 7            8          Bag      Fashion      NaN               12     3.9
# 8            9        Mouse  Electronics   1800.0                5     4.3
# 9            9          Cup  Electronics   1800.0                5     4.3
# 10          10     Keyboard  Electronics   2500.0                5     4.4
# 11          10         Haha  Electronics   2500.0                5     4.4
# 12          11       Bottle         Home    800.0                0     5.5
# 13          12        Chair    Furniture  -2500.0               10     4.0
# 14          12        Chair    Furniture  -2500.0               10     4.0
#
#            stock       seller         city      brand gender_target      age  \
# 0             25      TechHub    KathMandu       Dell        Unisex       25
# 1             40  GadgetNepal      Pokhara    Samsung        Unisex       30
# 2             60   FashionHub      Itahari       Nike          Male       22
# 3            150        Style   Biratnagar     Adidas        Female   Female
# 4   Out of Stock        TimeX    Kathmandu      Casio          Male       28
# 5             75     AudioPro      Pokhara        JBL        Unisex      24
# 6             25      TechHub    KATHMANDU       Dell        Unisex       25
# 7             45     CarryAll       Dharan  Wildcraft        Female       19
# 8            NaN      TechHub    Kathmandu   Logitech        Unisex      NaN
# 9            NaN      TechHub    Kathmandu   Logitech        Unisex      NaN
# 10            35     TechHub    Kathmandu    Logitech        Unisex       21
# 11            35     TechHub    Kathmandu    Logitech        Unisex       21
# 12           100    HomeStore     Janakpur    Generic        Unisex       26
# 13            -5      FurniCo     Lalitpur       IKEA        Unisex  Unknown
# 14            -5      FurniCo     Lalitpur       IKEA        Unisex  Unknown
#
#     reviews
# 0       120
# 1       210
# 2        55
# 3        30
# 4        80
# 5        65
# 6       120
# 7        18
# 8        90
# 9        90
# 10      110
# 11      110
# 12       12
# 13       44
# 14       44

# %%
# Out:
#   Cell In[23], line 3
#     bdd
#     ^
# IndentationError: unexpected indent

# %%
bdd["age"]=pd.to_numeric(bdd["age"],errors="coerce")
bdd["age"]= bdd["age"].fillna(bdd["age"].median())
bdd
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  13007.692308               15
# 2            3        Shoes      Fashion   3500.000000               5%
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000              NaN
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  13007.692308               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9            9          Cup  Electronics   1800.000000                5
# 10          10     Keyboard  Electronics   2500.000000                5
# 11          10         Haha  Electronics   2500.000000                5
# 12          11       Bottle         Home    800.000000                0
# 13          12        Chair    Furniture  -2500.000000               10
# 14          12        Chair    Furniture  -2500.000000               10
#
#     rating         stock       seller         city      brand gender_target  \
# 0      4.8            25      TechHub    KathMandu       Dell        Unisex
# 1      4.6            40  GadgetNepal      Pokhara    Samsung        Unisex
# 2      4.2            60   FashionHub      Itahari       Nike          Male
# 3      NaN           150        Style   Biratnagar     Adidas        Female
# 4      4.5  Out of Stock        TimeX    Kathmandu      Casio          Male
# 5      4.1            75     AudioPro      Pokhara        JBL        Unisex
# 6      4.8            25      TechHub    KATHMANDU       Dell        Unisex
# 7      3.9            45     CarryAll       Dharan  Wildcraft        Female
# 8      4.3           NaN      TechHub    Kathmandu   Logitech        Unisex
# 9      4.3           NaN      TechHub    Kathmandu   Logitech        Unisex
# 10     4.4            35     TechHub    Kathmandu    Logitech        Unisex
# 11     4.4            35     TechHub    Kathmandu    Logitech        Unisex
# 12     5.5           100    HomeStore     Janakpur    Generic        Unisex
# 13     4.0            -5      FurniCo     Lalitpur       IKEA        Unisex
# 14     4.0            -5      FurniCo     Lalitpur       IKEA        Unisex
#
#      age  reviews
# 0   25.0      120
# 1   30.0      210
# 2   22.0       55
# 3   24.5       30
# 4   28.0       80
# 5   24.0       65
# 6   25.0      120
# 7   19.0       18
# 8   24.5       90
# 9   24.5       90
# 10  21.0      110
# 11  21.0      110
# 12  26.0       12
# 13  24.5       44
# 14  24.5       44

# %%
#bdd.dropna()
#bdd[bdd.duplicated()]
bdd["discount_percent"] =bdd["discount_percent"].str.replace("%","")
bdd
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 2            3        Shoes      Fashion   3500                5     4.2
# 3            4      T-Shirt      Fashion   1500               20     NaN
# 4            5        Watch  Accessories   5500               10     4.5
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 7            8          Bag      Fashion    abc               12     3.9
# 8            9        Mouse  Electronics   1800                5     4.3
# 9            9          Cup  Electronics   1800                5     4.3
# 10          10     Keyboard  Electronics   2500                5     4.4
# 11          10         Haha  Electronics   2500                5     4.4
# 12          11       Bottle         Home    800                0     5.5
# 13          12        Chair    Furniture  -2500               10     4.0
# 14          12        Chair    Furniture  -2500               10     4.0
#
#            stock       seller         city      brand gender_target      age  \
# 0             25      TechHub    KathMandu       Dell        Unisex       25
# 1             40  GadgetNepal      Pokhara    Samsung        Unisex       30
# 2             60   FashionHub      Itahari       Nike          Male       22
# 3            150        Style   Biratnagar     Adidas        Female   Female
# 4   Out of Stock        TimeX    Kathmandu      Casio          Male       28
# 5             75     AudioPro      Pokhara        JBL        Unisex      24
# 6             25      TechHub    KATHMANDU       Dell        Unisex       25
# 7             45     CarryAll       Dharan  Wildcraft        Female       19
# 8            NaN      TechHub    Kathmandu   Logitech        Unisex      NaN
# 9            NaN      TechHub    Kathmandu   Logitech        Unisex      NaN
# 10            35     TechHub    Kathmandu    Logitech        Unisex       21
# 11            35     TechHub    Kathmandu    Logitech        Unisex       21
# 12           100    HomeStore     Janakpur    Generic        Unisex       26
# 13            -5      FurniCo     Lalitpur       IKEA        Unisex  Unknown
# 14            -5      FurniCo     Lalitpur       IKEA        Unisex  Unknown
#
#     reviews discout_percent
# 0       120              10
# 1       210              15
# 2        55               5
# 3        30              20
# 4        80              10
# 5        65             NaN
# 6       120              10
# 7        18              12
# 8        90               5
# 9        90               5
# 10      110               5
# 11      110               5
# 12       12               0
# 13       44              10
# 14       44              10
