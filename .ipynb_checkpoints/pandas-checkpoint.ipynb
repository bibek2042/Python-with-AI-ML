# %%
import pandas as pd

# %%
result = pd.Series(["nepal","china","America"],index=["a","b","c"])
print(result)
print(result["b"])
# Out:
# a      nepal
# b      china
# c    America
# dtype: str
# china

# %%
student_data = {
    "name" : ["Bibek","Upen","Nabin"],
    "age" : [21,10,11],
    "course" : ["ai_udaan","mern","react.js"]
  }
student_dataframe = pd.DataFrame(student_data)
print(student_dataframe)
# Out:
#     name  age    course
# 0  Bibek   21  ai_udaan
# 1   Upen   10      mern
# 2  Nabin   11  react.js

# %%
students_datas = pd.read_csv("datasets/student_datas.csv")
print(students_datas)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
dummy_datas = pd.read_excel("datasets/dummy.xlsx")
print(dummy_datas)
# Out:
#    Population Level Data Sources Available for Use by Service Providers in the Capital Region  \
# 0                                                 NaN
# 1   Purpose: The purpose of this spreadsheet is to...
# 2                         Version Date: Oct 9th, 2025
# 3   Author: Island Health's Population and Public ...
# 4   Contact: For questions, please contact Kirsten...
# ..                                                ...
# 70         Canadian Income Survey (Statistics Canada)
# 71                                BC Cancer Dashboard
# 72   BC Centre on Substance Use Drug Checking Results
# 73   2025 Point in Time Homelessness Count and Survey
# 74                        CRFAIR Research and Reports
#
#                                            Unnamed: 1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...

# %%
todos_datas = pd.read_json("datasets/todos.json")
print(todos_datas)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %%
nd = pd.read_csv("datasets/netflix_dataset.csv")
print(nd)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
import pandas as pd
st_data = pd.read_json("datasets/students_data.json")
#print(st_data)   
#print(st_data.head()) 
#print(st_data.tail(3))
#print(st_data.shape)
#print(st_data.columns)
#print(st_data.dtypes)
#print(st_data.info())
#print(st_data.describe())
#print(st_data["name"])
#print(st_data[["name","age"]])
#print(st_data.head(1))
#print(st_data.tail(1))
#print(st_data[st_data["id"]==5])
#print(st_data[st_data["district"]=="Kathmandu"])
#print(st_data[st_data["age"] > 21])
#print(st_data[st_data["gender"] == "Female"])
#print(st_data[st_data["attendance"] > 90 ])
#print(st_data[st_data["marks"] > 85 ])
#print(st_data[st_data["courses_enrolled"].apply(lambda x: "Python" in x)])
# Out:
#    id           name  age  gender       phone                     email  \
# 0   1  Sabina Pandey   19    Male  9866879003  sabina.pandey1@gmail.com
# 1   2   Sujan Poudel   28    Male  9870676580   sujan.poudel2@gmail.com
# 2   3   Nabin Pandey   26    Male  9834006426   nabin.pandey3@gmail.com
# 3   4   Roshan Regmi   27  Female  9811229824   roshan.regmi4@gmail.com
# 4   5   Anisha Regmi   25    Male  9824458163   anisha.regmi5@gmail.com
#
#     location   district province                        courses_enrolled  \
# 0     Dharan    Sunsari    Koshi                           [NodeJS, C++]
# 1  Nepalgunj      Banke  Lumbini                               [Flutter]
# 2  Kathmandu  Kathmandu  Bagmati  [Django, Deep Learning, Python, React]
# 3     Dharan    Sunsari    Koshi         [Figma, Python, Flutter, Excel]
# 4    Chitwan    Chitwan  Bagmati                          [Data Science]
#
#    fees_paid  fees_due  attendance  marks         batch   join_date  passed  \
# ...
